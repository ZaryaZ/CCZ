# %%
# Import modul google colab untuk akses dataset yang sudah diupload di google drive
from google.colab import drive
import os

# Akses direktori dari google drive penyimpanan dataset
dataset_path_1st ='/content/Data PD 2.csv'

# %%
dataset_path_1st = '/content/Data PD.csv'

# %%
# Import modul untuk akses dataset, mengakses dataframe, dan visualisasi
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.stats import entropy
from scipy.special import entr

# %%
pd.read_csv('/content/Data PD 2.csv')
# Out:
#      PD FASA R   PD FASA S   PD FASA T
# 0           1.7         1.7        1.3
# 1           1.7         1.6        1.2
# 2           2.0         1.6        1.2
# 3           2.0         1.7        1.2
# 4           1.7         1.7        1.2
# ..          ...         ...        ...
# 251         1.8         1.2        1.1
# 252         1.5         1.1        1.0
# 253         1.5         1.3        1.0
# 254         1.4         1.3        1.1
# 255         0.7         1.2        1.1
#
# [256 rows x 3 columns]

# %%
dataset = pd.read_csv('/content/Data PD 2.csv')

# %%
# Pembacaan dalam bentuk grafik salah satu data dari pengujian kedua
# dataset = pd.read_csv('/content/Data PD 2.csv', sep=';')
dataset.columns = ['Fasa R','Fasa S','Fasa T']
dataset.plot(figsize=(18,6)); # supaya gambarnya lebih besar

# %%
condition = [dataset['Fasa R'] < 1,
             dataset['Fasa R'] >= 1]
choice = ['Normal','Alarm']
dataset['Fasa R'] = np.select(condition,choice)

# %%
dataset['Fasa R'].value_counts()
# Out:
# Alarm     250
# Normal      6
# Name: Fasa R, dtype: int64

# %%
X = dataset.iloc[:,[0,1,2]]
y = dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=2021)
X_train
# Out:
#      Fasa R  Fasa S  Fasa T
# 42    Alarm     1.7     1.2
# 149  Normal     1.6     1.3
# 190   Alarm     1.6     1.3
# 108   Alarm     1.6     1.3
# 76    Alarm     1.7     1.3
# ..      ...     ...     ...
# 109   Alarm     1.6     1.3
# 128   Alarm     1.7     1.3
# 57    Alarm     1.6     1.2
# 85    Alarm     1.6     1.2
# 116   Alarm     1.6     1.3
#
# [192 rows x 3 columns]
